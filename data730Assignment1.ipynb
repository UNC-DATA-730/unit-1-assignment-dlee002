# %%
system('conda env list | grep data730', intern = TRUE)
# Out:
# [1] "data730               *  /home/studio-lab-user/.conda/envs/data730"

# %%
library('tidymodels')

# %%
toss_fair_coin_n_times = function(n_tosses = 250) {
    result = ifelse(runif(n = n_tosses) < 0.5, 'heads', 'tails')
    result
}

# %%
repeat_the_experiment = function(n_iterations, n_tosses = 250) {
    n_heads_each_iteration = c()
    for (i in 1:n_iterations) {
        n_heads = sum(toss_fair_coin_n_times(n_tosses) == 'heads')
        n_heads_each_iteration = c(n_heads_each_iteration, n_heads)
    } 
    n_heads_each_iteration
}

# %%
toss_fair_coin_n_times
# Out:
# function(n_tosses = 250) {
#     result = ifelse(runif(n = n_tosses) < 0.5, 'heads', 'tails')
#     result
# }

# %%
repeat_the_experiment
# Out:
# function(n_iterations, n_tosses = 250) {
#     n_heads_each_iteration = c()
#     for (i in 1:n_iterations) {
#         n_heads = sum(toss_fair_coin_n_times(n_tosses) == 'heads')
#         n_heads_each_iteration = c(n_heads_each_iteration, n_heads)
#     }
#     n_heads_each_iteration
# }

# %%
tidymodels_prefer()

# %%
library('tidymodels')

# %%
toss_fair_coin_n_times
# Out:
# function(n_tosses = 250) {
#     result = ifelse(runif(n = n_tosses) < 0.5, 'heads', 'tails')
#     result
# }

# %%
repeat_the_experiment
# Out:
# function(n_iterations, n_tosses = 250) {
#     n_heads_each_iteration = c()
#     for (i in 1:n_iterations) {
#         n_heads = sum(toss_fair_coin_n_times(n_tosses) == 'heads')
#         n_heads_each_iteration = c(n_heads_each_iteration, n_heads)
#     }
#     n_heads_each_iteration
# }

# %%
toss_fair_coin_n_times()
# Out:
#   [1] "heads" "tails" "tails" "heads" "heads" "tails" "heads" "tails" "heads"
#  [10] "heads" "tails" "tails" "tails" "tails" "tails" "heads" "heads" "tails"
#  [19] "tails" "heads" "heads" "heads" "tails" "heads" "heads" "tails" "tails"
#  [28] "heads" "tails" "heads" "tails" "tails" "tails" "heads" "heads" "tails"
#  [37] "tails" "heads" "heads" "tails" "tails" "heads" "tails" "heads" "heads"
#  [46] "heads" "tails" "heads" "heads" "tails" "heads" "heads" "tails" "tails"
#  [55] "heads" "heads" "heads" "tails" "heads" "heads" "tails" "heads" "tails"
#  [64] "heads" "tails" "tails" "heads" "tails" "tails" "heads" "heads" "tails"
#  [73] "heads" "tails" "tails" "tails" "tails" "heads" "tails" "heads" "heads"
#  [82] "tails" "tails" "heads" "tails" "heads" "heads" "heads" "heads" "heads"
#  [91] "heads" "heads" "heads" "heads" "tails" "tails" "tails" "heads" "tails"
# [100] "heads" "tails" "tails" "tails" "heads" "heads" "tails" "tails" "tails"
# ...

# %%
repeat_the_experiment()
# Out:
# Error in repeat_the_experiment(): argument "n_iterations" is missing, with no default
# Traceback:
#
# 1. repeat_the_experiment()

# %%
n_iterations = 10000

# %%
n_iterations
# Out:
# [1] 10000

# %%
n_tosses = 250

# %%
observed_deviation = 139 - 125

# %%
n_heads_each_experiment = repeat_the_experiment(n_iterations, n_tosses)

# %%
n_heads_each_experiment
# Out:
#     [1] 134 122 124 129 122 116 122 126 134 135 117 123 117 122 121 119 118 114
#    [19] 129 122 117 111 119 118 125 119 132 126 136 119 126 125 126 115 131 127
#    [37] 127 119 126 128 116 121 137 119 116 152 123 106 121 128 115 129 116 134
#    [55] 125 120 114 132 118 133 134 124 131 131 125 126 122 124 129 128 132 116
#    [73] 127 127 129 120 119 131 125 116 130 133 112 116 129 122 121 132 114 121
